# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.1.0'

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
X = np.array([1, 2, 5, 8, 12])

# %%
Y = np.array([3, 6, 7, 12, 9])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X,Y)
plt.show()

# %%
X = np.array([1, 2, 5, 8, 12])
Y = np.array([3, 6, 7, 12, 9])

import matplotlib.pyplot as plt
plt.plot(X, Y)
plt.title("this is the title")
plt.xlabel("X label")
plt.ylabel("Y label")
plt.show()

# %%
subjects = ["Maths", "Biology", "Chemistry", "Physics",
            "English", "Computers"]
marks = [97, 68, 59, 81, 77, 92]

# %%
plt.bar(subjects,marks,color='blue')
plt.title("Bar Graph Example")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
subjects = ["Maths", "Biology", "Chemistry", "Physics",
            "English", "Computers"]
student1 = [97, 68, 59, 81, 77, 92]
student2 = [88, 61, 80, 40, 62, 52]
student3 = [54, 62, 77, 54, 71, 98]

# %%
index = np.arange(6)
width = 0.03
plt.bar(index,student1,width,color="aqua",label="student1")
plt.bar(index+width,student2,width,color="green",label="student2")
plt.bar(index+(width*2),student3,width,color="blue",label="student3")
plt.title("Stacked Bar Graph Example")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.xticks(index+width/2,subjects)
plt.legend()
plt.show()

# %%
firms = ["Firm A", "Firm B", "Firm C", "Firm D", "Firm E"]
market_shares = [10, 40, 30, 5, 15]

# %%
Explode = [0, 0, 0, 0.5, 0]

# %%
plt.pie(market_shares,explode=Explode,labels=firms,
        shadow=True,startangle=45)
plt.axis('equal')
plt.legend(title="List of Firms")
plt.show()

# %%
x = np.random.randn(10000)

# %%
plt.title("Histogram Example")
plt.xlabel("Random Data")
plt.ylabel("Frequency")
plt.hist(x,10)
plt.show()

# %% [markdown]
# Creating 3D projections in Matplotlib is very simple. You need to import Axes3D, which registers the "3d" projection. Then create a subplot setting the projection to "3d". This returns an Axes3DSubplot object, which you can use to call plot_surface, giving x, y, and z coordinates, plus optional attributes.

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# %% [markdown]
# Here, linspace returns evenly spaced numbers over a specified interval. meshgrid returns coordinate matrices from coordinate vectors.
#
# Finally, we will create the figure, the subplot, and call the plot_surface with the coordinates we created earlier:

# %%
figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1,cstride=1,
                                 cmap=matplotlib.cm.coolwarm, 
                                 linewidth=0.1)
plt.show()

# %% [markdown]
# Getting Stared with Matplotlib - Create a Scatter Plot
# using Pyplot
#
# Scatter plots show how much one variable is affected by another. The relationship between two variables is called their correlation.

# %%
from numpy.random import rand

# %%
for color in ['red','green','blue']:
    n = 100
    x,y = rand(2,n)
    scale = 500.0**rand(n)**5
    plt.scatter(x,y,s=scale,c=color,alpha=0.3,edgecolor='blue')
    
plt.grid(True)
plt.show()

# %% [markdown]
# # Getting Stared with Matplotlib - Subplots in Matplotlib

# %%
plt.plot([1,4,7])
plt.subplot(2,1,1)
plt.plot(range(12))
plt.subplot(2,1,2, facecolor='red')
plt.plot(range(12))
plt.show()

# %% [markdown]
# We did this to demonstrate that creating a subplot will delete any pre-existing subplot that overlaps with it beyond sharing a boundary.
#
# Now, in the same cell as before, we will create a subplot using the subplot() function with top plot of a grid with 2 rows and 1 column. Since this subplot will overlap the first, the plot (and its axes) previously created, will be removed

# %% [markdown]
# The third line creates a second subplot with red background.
#
# You can add an insert plot in the same figure by adding another axes
# object in the same figure canvas. The matplotlib.figure module contains
# the Figure class. It is a top-level container for all plot elements. The Figure
# object is instantiated by calling the figure() function of the pyplot module.
# You
# can create it as follows:

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0, math.pi*2, 0.09)
fig=plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.9])
axes2 = fig.add_axes([0.62, 0.62, 0.3, 0.3])
y = np.sin(x)
axes1.plot(x, y, 'b')
axes2.plot(x,np.cos(x),'r')
axes1.set_title('sine')
axes2.set_title("cosine")
plt.show()

# %% [markdown]
# Here, axes1 is the main axes, and axes2 is the inset axes. You can test with different values to move and resize the charts.

# %%
import matplotlib.image as mpimg

# %%
path = 'https://cloudxlab.s3.amazonaws.com/static/images/aha/matplotlib/introduction_image.png'

# %%
img = mpimg.imread(path)
imgplot = plt.imshow(img)
